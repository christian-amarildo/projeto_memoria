# %% [markdown]
# # projetos de memória

# %% [markdown]
# ### projeto 1

# %% [markdown]
# Projete um sistema de memória que possui 13 pinos de endereços e um barramento de dados (BD) que transporta 2 palavras por vez. O BD não pode exceder 64 bits e a palavra deve ser maior que a célula da memória. A memória deve ter capacidade de 8 Gbits. Depois do projeto, indique qual é o tamanho da palavra, da célula, do BD e do barramento de endereços, e desenhe o chip.

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\projeto 1.2.jpeg')

# %% [markdown]
#    o chip desenhado atende aos requisitos do projeto, tendo 13 pinos de endereços, um barramento de dados (BD) que transporta 2 palavras por vez um que BD que não excede 64 bits, tendo 16 bits e a palavra é o mesmo que duas células.
#    Para isso, foi utiizado uma palavra de tamanho de 8 bits, uma célula de 4 bits,e um barramento de endereços de 31 bits resultando nos 8 Gbits de capacidade
#    considerando o BE, e o tamanho de cada célula, a capacidade foi resultado do seguinte calculo:

# %%
BE= 31
TC= 4
prefixo="bits"
if BE>=30:
    prefixo="Gbits"
    BE= BE-30
capacidade= 2**BE*TC
print(capacidade,prefixo)
# Out:
# 8 Gbits

# %% [markdown]
# ### projeto 2

# %% [markdown]
# Projete um sistema de memória que possui 16 linhas de dados (BD). Os pinos de endereço precisam ser menores que 14. A memória deve ter capacidade de 32 Gbits. Justifique cada decisão do projeto. Desenhe o chip. Qual é o tamanho do barramento de endereços?

# %%
from IPython.display import Image
Image(filename=r'C:\Users\chris\Downloads\projeto 2.3.jpeg')

# %% [markdown]
# Projete um sistema de memória que possui 16 linhas de dados (BD). Os pinos de endereço precisam ser menores que 14. A memória deve ter capacidade de 32 Gbits. Justifique cada decisão do projeto. Desenhe o chip. Qual é o tamanho do barramento de endereços?
#
# O chip atende os requisitos do projeto tendo 16 linha de dados, os pinos de endereço são 13, sendo menor que 14 e a capacidade total é de 32 Gbits.
# Para isso, foi utilizado 13 pinos de endereço, juntamente com um ras e um cas, mais 16 bancos, totalizando 2 G de endereços. valor escolhido para que ao multiplicar com o tamanho de uma célula, seja possível obter 32 Gbits de capacidade e atender de forma mais simples o requisito de linha de dados no final, que é 16.
# o barramento de endereço ficou sendo de 31 bits
#
# O total de endereços e a capacidade máxima do chip se deu apartir do seguinte cálculo:

# %%
enderecos=13
rascas=2
bancos=16
BE= enderecos+rascas+bancos
TC= 16
prefixo="bits"
if BE>=30:
    prefixo="Gbits"
    BE= BE-30
capacidade= 2**BE*TC
print(capacidade,prefixo)
# Out:
# 32 Gbits
